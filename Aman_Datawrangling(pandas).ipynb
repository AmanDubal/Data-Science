# %%
import pandas as pd
df = pd.DataFrame()

# %%
Data ="/content/sample_data/california_housing_test.csv"
df=pd.read_csv(Data)
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
format(df.shape)
# Out:
# '(3000, 9)'

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
print("---------------select the first row \n",df.iloc[0])
print("\n -------------select three row \n",df.iloc[1:4])
print("\n ---------------all rows up to 4 including four \n",df.iloc[:4])
# Out:
# ---------------select the first row
#  longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64
#
#  -------------select three row
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
#
#    population  households  median_income  median_house_value
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
#
# ...

# %% [markdown]
# Selecting Rows Based on Conditionals

# %%
df[df['housing_median_age']==27.0].head(2)
# Out:
#            longitude  latitude  housing_median_age  total_rooms  \
# longitude
# -122.05      -122.05     37.37                27.0       3885.0
# -117.81      -117.81     33.78                27.0       3589.0
#
#            total_bedrooms  population  households  median_income  \
# longitude
# -122.05             661.0      1537.0       606.0         6.6085
# -117.81             507.0      1484.0       495.0         5.7934
#
#            median_house_value
# longitude
# -122.05              344700.0
# -117.81              270500.0

# %%
df['housing_median_age'].replace(27.0,20.1).head(2)
# Out:
# longitude
# -122.05    20.1
# -118.30    43.0
# Name: housing_median_age, dtype: float64

# %%
df['housing_median_age'].replace([27.0,20.1],[43.0,28.0]).head(2)
# Out:
# longitude
# -122.05    43.0
# -118.30    43.0
# Name: housing_median_age, dtype: float64

# %% [markdown]
# Renaming columns

# %%
df.rename(columns={'longitude':'diameter'}).head(2)
# Out:
#            diameter  latitude  housing_median_age  total_rooms  \
# longitude
# -122.05     -122.05     37.37                27.0       3885.0
# -118.30     -118.30     34.26                43.0       1510.0
#
#            total_bedrooms  population  households  median_income  \
# longitude
# -122.05             661.0      1537.0       606.0         6.6085
# -118.30             310.0       809.0       277.0         3.5990
#
#            median_house_value
# longitude
# -122.05              344700.0
# -118.30              176500.0

# %%
print('Maximum: {}'.format(df['housing_median_age'].max()))
print('Minimum: ()'.format(df['housing_median_age'].min()))
print('Mean: {}'.format(df ['housing_median_age'].mean()))
print('Sum: '.format(df ['housing_median_age'].sum()))
print('Count: {}'.format(df ['housing_median_age'].count()))
# Out:
# Maximum: 52.0
# Minimum: ()
# Mean: 28.845333333333333
# Sum:
# Count: 3000

# %%
print("Variance: ()\n".format(df.var()))
print("\nStandard Deviation: {}\n".format(df.std()))
print("\nKurtosis: {}\n".format(df.kurt()))
print("\nSkewness:{}\n".format(df.skew()))
# Out:
# Variance: ()
#
#
# Standard Deviation: longitude                  1.994936
# latitude                   2.129670
# housing_median_age        12.555396
# total_rooms             2155.593332
# total_bedrooms           415.654368
# population              1030.543012
# households               365.422710
# median_income              1.854512
# median_house_value    113119.687470
# dtype: float64
#
#
# Kurtosis: longitude             -1.362772
# latitude              -1.124372
# housing_median_age    -0.803784
# total_rooms           32.099941
# total_bedrooms        28.537071
# population            16.443268
# households            26.229361
# median_income          5.626184
# median_house_value     0.395399
# dtype: float64
#
#
# Skewness:longitude            -0.297858
# latitude              0.459816
# housing_median_age    0.018513
# total_rooms           4.167637
# total_bedrooms        3.863393
# population            2.949671
# households            3.559753
# ...

# %%
df['median_income'].unique()
# Out:
# array([6.6085, 3.599 , 5.7934, ..., 3.3906, 2.2895, 8.5608])

# %%
df.drop('housing_median_age',axis=1).head(2)
# Out:
#            longitude  latitude  total_rooms  total_bedrooms  population  \
# longitude
# -122.05      -122.05     37.37       3885.0           661.0      1537.0
# -118.30      -118.30     34.26       1510.0           310.0       809.0
#
#            households  median_income  median_house_value
# longitude
# -122.05         606.0         6.6085            344700.0
# -118.30         277.0         3.5990            176500.0

# %%
df[df['population']!=310].head(2)
# Out:
#            longitude  latitude  housing_median_age  total_rooms  \
# longitude
# -122.05      -122.05     37.37                27.0       3885.0
# -118.30      -118.30     34.26                43.0       1510.0
#
#            total_bedrooms  population  households  median_income  \
# longitude
# -122.05             661.0      1537.0       606.0         6.6085
# -118.30             310.0       809.0       277.0         3.5990
#
#            median_house_value
# longitude
# -122.05              344700.0
# -118.30              176500.0

# %% [markdown]
# Grouping Rows by Values

# %%
df.groupby('population').mean()
# Out:
#             longitude  latitude  housing_median_age  total_rooms  \
# population
# 5.0          -114.620     33.62                26.0         18.0
# 8.0          -117.035     33.26                26.5         11.0
# 14.0         -117.775     33.35                50.5         28.5
# 19.0         -122.490     38.00                26.0         48.0
# 21.0         -118.060     34.03                36.0         21.0
# ...               ...       ...                 ...          ...
# 8824.0       -117.120     33.49                 4.0      21988.0
# 9419.0       -117.200     33.58                 2.0      30450.0
# 10877.0      -117.270     33.15                 4.0      23915.0
# 11139.0      -116.140     34.45                12.0       8796.0
# 11935.0      -121.530     38.48                 5.0      27870.0
#
#             total_bedrooms  households  median_income  median_house_value
# population
# 5.0                    3.0         3.0        0.53600            275000.0
# ...

# %%
df.groupby('population')['housing_median_age'].count()
# Out:
# population
# 5.0        1
# 8.0        2
# 14.0       2
# 19.0       1
# 21.0       1
#           ..
# 8824.0     1
# 9419.0     1
# 10877.0    1
# 11139.0    1
# 11935.0    1
# Name: housing_median_age, Length: 1802, dtype: int64

# %%
df.groupby('total_rooms	').apply(lamba x: x.count())
